# %%
from point import Point6D
from robot import Robot

# %%
robot = Robot()
robot.connect()
# Out:
# Connected to 10.181.116.41:54602

# %%
P1 = Point6D(name="P1", x=300, y=0, z=600, a=80, b=80, c=90)
P2 = Point6D(name="P2", x=300, y=0, z=700, a=80, b=80, c=90)

# %%
robot.ptp(P2, vel=10)
# Out:
# Move sent:
# <?xml version="1.0" encoding="UTF-8"?>
# <EthernetKRL>
# <RobotCommand Id="2" Type="1"><Move Mode="2" BaseIndex="0" ToolIndex="0" Velocity="10" Acceleration="0.5" Blending="0.0" WaitForGripper="0"><Cartesian X="300" Y="0" Z="700" A="80" B="80" C="90" /><Cartesian_Aux X="0" Y="0" Z="0" A="0" B="0" C="0" /><Joint A1="0" A2="0" A3="0" A4="0" A5="0" A6="0" /></Move></RobotCommand>
# </EthernetKRL>

# %%
robot.touchup("P99", "points.csv")
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 203
# ---------------------------------------------------------------------------
# ParseError                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[70], line 1
# ----> 1 robot.touchup("P99", "points.csv")
#
# File ~/Dokumente/KRL2Python/2526ws_BH_KRL2Python/motion_controller.py:19, in MotionController.touchup(self, name, csv_file)
#      18 def touchup(self, name: str, csv_file: str):
# ---> 19     point = self.get_current_pose(name)
#      20     save_point_csv(csv_file, point)
#
# File ~/Dokumente/KRL2Python/2526ws_BH_KRL2Python/motion_controller.py:16, in MotionController.get_current_pose(self, name)
#      15 data = self.transport.receive(4096)
# ---> 16 return point_from_state(data, name)
#
# File ~/Dokumente/KRL2Python/2526ws_BH_KRL2Python/state_parser.py:5, in point_from_state(xml_bytes, name)
# ...

# %%
try:
    data = robot.motion_transport.receive(4096)
    print(data)
except:
    print("nichts")
# Out:
# b'5="21.880953" A6="-46.044670" A7=""></Joint><Cartesian X="300.001587" Y="0.002642" Z="699.999512" A="80.000671" B="79.999954" C="90.000031"></Cartesian></Position><Velocity A1="0.000000" A2="0.076306" A3="-0.076292" A4="0.228889" A5="-0.076292" A6="0.000000"></Velocity><Torque A1="" A2="" A3="" A4="" A5="" A6=""></Torque><Gripper><Jaw Position="" Status=""></Jaw><Vacuum Suction="" Force1="" Force2="" Cylinder=""></Vacuum></Gripper><Info Code="" Message=""></Info><Error Code="" Message=""></Error></RobotState><RobotState><Command Id="0" Finished_Id="0" Stopped="0"></Command><Position><Joint A1="-3.296524" A2="-97.819252" A3="80.281563" A4="38.104637" A5="21.881023" A6="-46.044670" A7=""></Joint><Cartesian X="300.001587" Y="0.002642" Z="699.999512" A="80.000671" B="79.999954" C="90.000031"></Cartesian></Position><Velocity A1="-0.076292" A2="0.000000" A3="0.000000" A4="0.076292" A5="0.000000" A6="0.000000"></Velocity><Torque A1="" A2="" A3="" A4="" A5="" A6=""></Torque><Gripper><Jaw P
# ...

# %%
robot.disconnect()
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 202
